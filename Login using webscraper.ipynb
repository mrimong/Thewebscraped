# %% [markdown]
# ## Login using a scraper

# %%
from bs4 import BeautifulSoup #For BeautifulSoup
import requests #For requests
import time #For sleep
import re #For regular expressions
import os #For saving files

# %% [markdown]
# #### Automating Login on The Old Reader
#
#
# Automating the process of logging into https://theoldreader.com

# %%
#Setting the url for oldreader
url_p3='https://theoldreader.com'
#Setting user agent
headers={'User-Agent':'Mozilla/5.0'}
#Setting a timer before requesting new information
time.sleep(10)
#Requesting information
p3_url=requests.get(url1,headers)
#Parsing the content 
soup3=BeautifulSoup(p3_url.content,'html.parser')
#Printing the content
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:title"/>
#   <meta content="SF bay area free stuff - craigslist" name="description"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:description"/>
#   <meta content="https://sfbay.craigslist.org/search/zip" property="og:url"/>
#   <title>
#    SF bay area free stuff - craigslist
#   </title>
#   <link href="https://sfbay.craigslist.org/search/zip" rel="canonical"/>
#   <link href="https://sfbay.craigslist.org/search/zip" hreflang="x-default" rel="alternate"/>
#   <link href="/favicon.ico" id="favicon" rel="icon">
#    <script id="ld_searchpage_data" type="application/ld+json">
# ...

# %% [markdown]
# ##### 1. Creating and Verifying a The Old Reader Account
# Account Creation:  Create an account on https://theoldreader.com.  Use an email address and password

# %% [markdown]
# **Credentials**
#
# emailid- mguha@ucdavis.edu
# password- mgucdavis@123
#
# Above are my credentials, I have tried manually logging in to the website.

# %% [markdown]
# ##### Exploring the Login Mechanism
# Navigating to the login page of https://theoldreader.com
#
#
# Documenting all `<input>` fields within the login form, paying special attention to their name attributes. These fields are crucial for submitting the login request programmatically.

# %%
# Below is the URL for the login page of the website
urlp3='https://theoldreader.com/users/sign_in'
#Setting user agent
headers={'User-Agent':'Mozilla/5.0'}
#Setting a timer before requesting new information
time.sleep(10)
#Requesting information
p3_url=requests.get(urlp3,headers)
#Parsing the content 
soup3=BeautifulSoup(p3_url.content,'html.parser')

#Printing the input field names
inputs=soup3.select('input')
print("The different input fields in the login form are as follows:\n")
for i in inputs:
    print(i.get('name'))
# Out:
# The different input fields in the login form are as follows:
#
# utf8
# authenticity_token
# user[login]
# user[password]
# commit

# %% [markdown]
# ##### Analyzing Network Traffic for Login Request
# POST request seems to be submitted at the time of login. This method is chosen as it does not store the credential information in the browser history (unlike GET), it is used for sending information especially in terms of forms on a website. It is more secure.
#
# Carefully examine the payload that was submitted to the server during login.  Compare this payload to the `<form>` / `<input>` fields you previously analyzed.  Explain your observation
#
# These are the fields that are being displayed in the payload section.
# * utf8
# * authenticity_token
# * user[login]
# * user[password]
# * commit
#
# From the input fields, we can see that these are exactly the same fields that are inputs in the previous login page.

# %% [markdown]
# #####  Automating the Login Process
# Using Python and appropriate libraries like requests, simulating the login process.
#
# Creating a session object to maintain your login state across multiple requests.
#
# Preparing a payload with your login credentials and other necessary form data identified from the login page and the network analysis.
#
# Sending a POST request to the login form’s action URL to log in, using the session object.

# %%
#Selecting the login form which has a id="new_user"
form=soup3.select_one('#new_user')
#DATA ESSENTIAL FOR LOGIN from PAYLOAD and NETWORK ANALYSIS
input=form.select_one('input[name=authenticity_token]')
auth=input.get('value')
commit=form.select_one('input[name=commit]').get('value')
utf=form.select_one('input[name=utf8]').get('value')
#Creating a session
time.sleep(10)

session_hw=requests.session()
#Sending POST Request to login using session object
session=session_hw.post('https://theoldreader.com/users/sign_in'
             ,data=
            {'authenticity_token':auth,
            'commit':commit,
             'utf8':utf,
             'user[login]:':'mguha@ucdavis.edu',
             'user[password]:':'mgucdavis@123'
            },
             timeout=20)
print(session_hw)

# %% [markdown]
# #####
# After attempting to log in, inspecting the cookies saved in the session object to understand the information The Old Reader stores on computer.
#
# Using the session object to access https://theoldreader.com.
#
# Verifying successful login by checking for the presence of your user information that is only available when logged in.

# %%
#Setting the url
url5='https://theoldreader.com/users/sign_in'
headers={'User-Agent':'Mozilla/5.0'}
#Sending request
page=requests.get(url5,headers)
#Parsing page
pagesp=BeautifulSoup(page.content,'html.parser')
#Selecting the form which has id: new_user, authenticity_token, 
form=pagesp.select_one('#new_user')
input=form.select_one('input[name=authenticity_token]')
auth=input.get('value')

time.sleep(10)
#Create a session
session=requests.session()

session.post(peturl
             ,data=
            {'authenticity_token':auth,
             'user[login]':'mguha@ucdavis.edu',
             'user[password]':'mgucdavis@123'
            },
             timeout=20)
cookies=session.cookies.get_dict()
print("\n---------------------COOKIES------------------------------------------")
print(cookies)
#To verify successful login 
time.sleep(10)
purl2='https://theoldreader.com/users/edit'
page2=session.get(purl2,cookies=cookies)
soup2=BeautifulSoup(page2.content,'html.parser')
#print(soup2.prettify())
#To check if we have our username in the website and our login credentials are visible or not
#elements=soup2.find_all(string="mguha@ucdavis.edu")
print("\n-----------------------------------------")
zi=soup2.select_one('#user_email')
zi
# Out:
# ---------------------COOKIES------------------------------------------
# {'remember_user_token': 'BAhbB1sGVToaTW9wZWQ6OkJTT046Ok9iamVjdElkIhG%2FeZ8MkhONnrGfmctJIiIkMmEkMDUkUkd0TnpuYUM4aXc1cmFzSS9abGxwZQY6BkVU--d822610a871668657b8e249bd6d6246a902e2256', 'i_know_you': 'mg', '_new_reader_session': 'BAh7CkkiD3Nlc3Npb25faWQGOgZFVEkiJTAzYmQ1YjI2NDkxMTM5ZDE2NzY1ZmRiZjQ4MGE3NGY1BjsAVEkiGXdhcmRlbi51c2VyLnVzZXIua2V5BjsAVFsHWwZVOhpNb3BlZDo6QlNPTjo6T2JqZWN0SWQiEb95nwySE42esZ%2BZy0kiIiQyYSQwNSRSR3ROem5hQzhpdzVyYXNJL1psbHBlBjsAVEkiDWxhbmd1YWdlBjsARjoHZW5JIhByZWRpcmVjdF90bwY7AEZJIgYvBjsARkkiEF9jc3JmX3Rva2VuBjsARkkiMThETjR3REJzMm9sQ2FxN3h5bk83QjRSVHFucDlBQ3B1MXhKVzRBOWQxbGM9BjsARg%3D%3D--8008043c82bfb7bd515ac57219e603896b3d2210', 'signed_at': '1707297490'}
#
# -----------------------------------------
# <input class="form-control" id="user_email" name="user[email]" size="30" type="email" value="mguha@ucdavis.edu"/>
